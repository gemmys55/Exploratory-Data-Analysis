# %% [markdown]
# ## Employees Details Exploratory Data Analysis

# %% [markdown]
# ### Import neccessary modules & datafile(myexcel.csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv('myexcel.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.notnull()
# Out:
#      Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 0    True  True    True      True  True    True    True     True    True
# 1    True  True    True      True  True    True    True     True    True
# 2    True  True    True      True  True    True    True     True   False
# 3    True  True    True      True  True    True    True     True    True
# 4    True  True    True      True  True    True    True    False    True
# ..    ...   ...     ...       ...   ...     ...     ...      ...     ...
# 453  True  True    True      True  True    True    True     True    True
# 454  True  True    True      True  True    True    True    False    True
# 455  True  True    True      True  True    True    True    False    True
# 456  True  True    True      True  True    True    True     True    True
# 457  True  True    True      True  True    True    True     True    True
#
# [458 rows x 9 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### column height is having incorrect data, changing the data of that particular column with any random numbers between 150 and 180.

# %%
df['Height']
# Out:
# 0      06-Feb
# 1      06-Jun
# 2      06-May
# 3      06-May
# 4      06-Oct
#         ...
# 453    06-Mar
# 454    06-Jan
# 455    07-Mar
# 456       7-0
# 457    07-Mar
# Name: Height, Length: 458, dtype: object

# %%
random_numbers = np.random.randint(150, 180, size=len(df))
df['Height'].fillna(pd.Series(random_numbers), inplace=True)
df['Height']
# Out:
# 0      170.816286
# 1      161.777213
# 2      167.854716
# 3      162.522021
# 4      177.846670
#           ...
# 453    161.841542
# 454    161.402227
# 455    171.298048
# 456    163.510337
# 457    151.003686
# Name: Height, Length: 458, dtype: float64

# %%
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  170.816286     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  161.777213     235
# 2     John Holland  Boston Celtics      30       SG   27  167.854716     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  162.522021     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.846670     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  161.841542     203
# 454      Raul Neto       Utah Jazz      25       PG   24  161.402227     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  171.298048     256
# 456    Jeff Withey       Utah Jazz      24        C   26  163.510337     231
# 457       Priyanka       Utah Jazz      34        C   25  151.003686     231
#
# ...

# %% [markdown]
# # Providing a dataset of employees working in ABC company. It consists of 458 rows and 9 columns. The company needs the detailed report and explanation of their employees in each team, also need to identify the following

# %% [markdown]
# ## 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
team_counts = df['Team'].value_counts()

# Percentage split with respect to the total employees
percentage_split = team_counts / len(df) * 100

# Display the counts and percentages
team_info = pd.DataFrame({'Team Count': team_counts, 'Percentage Split': percentage_split})
print(team_info)
# Out:
#                         Team Count  Percentage Split
# Team
# New Orleans Pelicans            19          4.148472
# Memphis Grizzlies               18          3.930131
# Utah Jazz                       16          3.493450
# New York Knicks                 16          3.493450
# Milwaukee Bucks                 16          3.493450
# Brooklyn Nets                   15          3.275109
# Portland Trail Blazers          15          3.275109
# Oklahoma City Thunder           15          3.275109
# Denver Nuggets                  15          3.275109
# Washington Wizards              15          3.275109
# Miami Heat                      15          3.275109
# Charlotte Hornets               15          3.275109
# Atlanta Hawks                   15          3.275109
# San Antonio Spurs               15          3.275109
# Houston Rockets                 15          3.275109
# Boston Celtics                  15          3.275109
# Indiana Pacers                  15          3.275109
# ...

# %%
import matplotlib.pyplot as plt

colors = ['steelblue', 'red', 'green', 'yellow', 'skyblue']
plt.bar(team_counts.index,team_counts.values,color=colors)
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.title('Percentage Splitting of Employees w.r.t each Team')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# #### By analysing the above bar graph , it is clear that the team "New Orleans Pelicans" has more percentage split compared with other teams

# %% [markdown]
# ## 2.Segregate the employees w.r.t different positions.

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
df[['Position','Name']]
# Out:
#     Position           Name
# 0         PG  Avery Bradley
# 1         SF    Jae Crowder
# 2         SG   John Holland
# 3         SG    R.J. Hunter
# 4         PF  Jonas Jerebko
# ..       ...            ...
# 453       PG   Shelvin Mack
# 454       PG      Raul Neto
# 455        C   Tibor Pleiss
# 456        C    Jeff Withey
# 457        C       Priyanka
#
# [458 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'Position' is a column in it
position_counts = df['Position'].value_counts()
colors = ['blue', 'red', 'black', 'yellow', 'green']

plt.bar(position_counts.index, position_counts.values, color=colors)
plt.xlabel('Position')
plt.ylabel('Employee Count')
plt.title('Employee Count by Position')
plt.show()

# %% [markdown]
# ### 3.Find from which age group most of the employees belong to.

# %%
df['Age']
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
age_counts = df['Age'].value_counts()
most_common_age = age_counts.idxmax()

print(f"The age group with the most employees is around {most_common_age} years.")
# Out:
# The age group with the most employees is around 24 years.

# %%
df['Age Group'] = df['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 and above')))
df
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  170.816286     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  161.777213     235
# 2     John Holland  Boston Celtics      30       SG   27  167.854716     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  162.522021     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  177.846670     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  161.841542     203
# 454      Raul Neto       Utah Jazz      25       PG   24  161.402227     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  171.298048     256
# 456    Jeff Withey       Utah Jazz      24        C   26  163.510337     231
# 457       Priyanka       Utah Jazz      34        C   25  151.003686     231
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Create a bar chartadf['Age Group'].value_counts()
age_group_counts=df['Age Group'].value_counts()
plt.hist(df['Age'],color='yellow',edgecolor='red')
plt.title('Distribution of Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Individuals')
plt.show()

# %% [markdown]
# ### 4.Find out under which team and position, spending in terms of salary is high

# %%
import pandas as pd

# Assuming 'df' is your DataFrame with columns 'Team', 'Position', and 'Salary'
# Replace 'Salary' with the actual column name for salary in your DataFrame
team_position_salary = df.groupby(['Team', 'Position'])['Salary'].sum()

max_spending_team_position = team_position_salary.idxmax()
max_spending_value = team_position_salary.max()

print(f"The team and position withs spending in terms of salary is high {max_spending_team_position} with a total spending of {max_spending_value}.")
# Out:
# The team and position withs spending in terms of salary is high ('Los Angeles Lakers', 'SF') with a total spending of 31866445.0.

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with columns 'Salary' and 'Age'
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Salary'], color='blue', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Scatter Plot of Salary vs Age')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with a 'Salary' column
plt.figure(figsize=(12, 8))
sns.boxplot(x='Team', y='Salary', data=df, palette='Set3')
plt.xlabel('Team')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Team')
plt.show()

# %% [markdown]
# ### 5.Find if there is any correlation between age and salary , represent it visually.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Age', 'Salary']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Age and Salary')
plt.show()

# %% [markdown]
# ## I conclude after the Employees Details Exploratory Data Analysis  :

# %% [markdown]
# ### 1.'New Orleans Pelicans' has the highest number of employees in the Team is with respect to the other team.

# %% [markdown]
# ### 2.The most number of employees are belongs to 'SG' Position, and least number of employees belongs to 'C' Position.

# %% [markdown]
# ### 3.Most employees are belongs to the age group of 20 - 30 years, Least in 10-20.

# %% [markdown]
# ### 4.The team 'Los Angels Lakers'and 'SF' Position are spending more in terms of salary.Clearly shown in max_salary_row we have calculated

# %% [markdown]
# ### 5.The employees in the age group of 30-40 years have the highest salary, as the age increase the salary also increasing.
